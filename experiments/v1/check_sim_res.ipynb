# %%
import pandas as pd
from visuals import get_ratings, plot_user_ratings

DATA_DIR = 'sim_res/episode_1_gpt3/'
FILE= 'episode_1_gpt-3.5-turbo-0301.csv'
df = pd.read_csv(f'{DATA_DIR}/{FILE}')

# %%
plot_df = get_ratings(df)
plot_user_ratings(plot_df, plot_dir=DATA_DIR, episode_id='episode_1', model='gpt-3.5-turbo-0301', pdf=False)

# %%
df
# Out:
#    message_type                                             prompt
# 0        system                                                NaN  \
# 1        system  System: Assistant has just had the below conve...
# 2        system  System: Assistant has just had the below conve...
# 3        system  System: Assistant has just had the below conve...
# 4        system  System: Assistant has just had the below conve...
# 5        system  System: Assistant has just had the below conve...
# 6        system  System: Assistant has just had the below conve...
# 7        system  System: Assistant has just had the below conve...
# 8        system  System: Assistant has just had the below conve...
# 9        system  System: Assistant has just had the below conve...
# 10       system  System: Assistant has just had the below conve...
# 11    assistant  System: You are a helpful AI assistant. Your a...
# 12    assistant  System: Principles guiding AI on human rights ...
# ...
